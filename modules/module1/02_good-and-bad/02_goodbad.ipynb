# %% [raw]
# ---
# title: "2 - Good and Bad Data Visualizations"
# subtitle: "Week 1<br>8/27/2024 <br>💻 🧰 📊 🥳"
# author: "Jessica Cooperstone, Ph.D."
# format:
#   revealjs:
#     incremental: true
#     theme: simple
#     footer: "[01 Principles](https://www.rdataviz.com/), © Jessica Cooperstone, 2024"
# ---

# %% [markdown]
# ```{css, echo=FALSE}
# .title {
#   font-size: 10px;
# }
# ```
#
#
# # Housekeeping
#
# - Questions from the previous class?
# - Take [edX R basics class](https://pll.harvard.edu/course/data-science-r-basics) if you don't have R experience
# - Start think about identifying a dataset for your capstone assignment
# - Don't forget about your reflections 🪞
#
# # Office hours
#
# - Jess: Tuesdays 1-2pm Howlett 348 or via [Zoom](https://go.osu.edu/dataviz-zoom)
# - Daniel: Thursdays 2-3pm Howlett 340 or via [Zoom](https://go.osu.edu/dataviz-zoom) (tell Daniel by the start of office hours if you're planning to attend)
# - Those who want to attend office hours virtually, use the same [Zoom link](https://go.osu.edu/dataviz-zoom) for class
#
#
#
# ## What was easier to find?
#
# - good 👏  visualizations
# - bad 😡 visualizations
#
#
# # Bad visualizations 😡 {.center_title}
#
# # Maps 🗺 Caleb {.r-fit-text}
#
# ![](bad/thompson.png){fig-align="center"}
#
# # The worst! Berenice 🏅 {.r-fit-text}
#
# ![](bad/winner_berenice.png){fig-align="center"}
#
# # Good visualizations 👏 {.center_title}
#
# # Pie charts can be good 🥧 Avonti {.center_title .smaller}
#
# ![](good/avonti.png){fig-align="center"}
#
# # Soil and small multiples 🚜 Mithlesh {.smaller}
#
# ![](good/mithlesh.jpg){fig-align="center"}
#
# # Who understands science? 🔬 Prabath {.r-fit-text}
#
# ![](good/prabath.png){fig-align="center"}
#
# # Voting by region 🗳️ John{.r-fit-text}
#
# ![](good/tengatenga.png){fig-align="center"}
#
# # Growing petunias 🌸 Alexandra {.r-fit-text}
#
# ![](good/alexandra.png){fig-align="center"}
#
# # Where do people live? 🗺️ Swetha 🏅 {.r-fit-text}
#
# ![](good/winner_swetha.png){fig-align="center"}
#
# # Closing thoughts
